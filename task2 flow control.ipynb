# %%
number = float(input("Enter a number: "))
if number > 0:
    print("The number is Positive.")
elif number < 0:
    print("The number is Negative.")
else:
    print("The number is Zero.")
# Out:
# Enter a number:  -876
# The number is Negative.

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("You are allowed to enter the theater.")
else:
    print("You must be 18 or older to enter the theater.")
# Out:
# Enter your age:  14
# You must be 18 or older to enter the theater.

# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print("The number is divisible by 2.")
else:
    print("The number is not divisible by 2.")
# Out:
# Enter a number:  24
# The number is divisible by 2.

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
if num1 > num2:
    print(f"The greater number is: {num1}")
elif num1 < num2:
    print(f"The greater number is: {num2}")
else:
    print("Both numbers are equal.")
# Out:
# Enter the first number:  34
# Enter the second number:  54
# The greater number is: 54.0

# %%
char = input("Enter a character: ")
if char.isupper():
    print("The character is uppercase.")
elif char.islower():
    print("The character is lowercase.")
else:
    print("The character is not a letter.")
# Out:
# Enter a character:  SPANDAN
# The character is uppercase.

# %%
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0):
    print("The year is a leap year.")
else:
    print("The year is not a leap year.")
# Out:
# Enter a year:  2008
# The year is a leap year.

# %%
time = int(input("Enter the time (0-23): "))
if time < 12:
    print("Good Morning!")
elif 12 <= time < 17:
    print("Good Afternoon!")
else:
    print("Good Evening!")
# Out:
# Enter the time (0-23):  22
# Good Evening!

# %%
score = float(input("Enter the student's score: "))
if score >= 75:
    print("Distinction")
elif 35 <= score < 75:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter the student's score:  80
# Distinction

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b and a > c:
    print("Largest number is:", a)
elif b > a and b > c:
    print("Largest number is:", b)
else:
    print("Largest number is:", c)
# Out:
# Enter first number:  32
# Enter second number:  45
# Enter third number:  89
# Largest number is: 89

# %%
units = int(input("Enter electricity units: "))

if units < 100:
    bill = units * 2
elif units <= 300:
    bill = units * 4
else:
    bill = units * 6

print("Electricity Bill = ", bill)
# Out:
# Enter electricity units:  34
# Electricity Bill =  68

# %%
a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))

if a == b == c:
    print("Equilateral Triangle")
elif a == b or b == c or a == c:
    print("Isosceles Triangle")
else:
    print("Scalene Triangle")
# Out:
# Enter first side:  12
# Enter second side:  13
# Enter third side:  34
# Scalene Triangle

# %%
salary = int(input("Enter salary: "))

if salary > 50000:
    bonus = salary * 0.20
elif salary >= 30000 and salary <= 50000:
    bonus = salary * 0.10
else:
    bonus = salary * 0.05

print( bonus)
# Out:
# Enter salary:  3653
# 182.65

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "spandan" and password == "1234":
    print("Login Successful")
else:
    print("Invalid Username or Password")
# Out:
# Enter username:  sonu
# Enter password:  655
# Invalid Username or Password

# %%
num = int(input("Enter a number: "))

if num % 3 == 0 and num % 5 == 0:
    print("Multiple of both 3 and 5")
elif num % 3 == 0:
    print("Multiple of only 3")
elif num % 5 == 0:
    print("Multiple of only 5")
else:
    print("None")
# Out:
# Enter a number:  40
# Multiple of only 5

# %%
age = int(input("Enter age: "))

if age >= 0 and age <= 12:
    print("Child")
elif age >= 13 and age <= 19:
    print("Teenager")
elif age >= 20 and age <= 59:
    print("Adult")
else:
    print("Senior Citizen")
# Out:
# Enter age:  19
# Teenager

# %%
age = int(input("Enter age: "))

if age < 5:
    print("Ticket Price = Free")
elif age >= 5 and age <= 18:
    print("Ticket Price = ₹100")
elif age >= 60:
    print("Ticket Price = ₹150")
else:
    print("Ticket Price = ₹200")
# Out:
# Enter age:  32
# Ticket Price = ₹200

# %%
balance = 10000

print("1. Check Balance")
print("2. Withdraw Money")
print("3. Deposit Money")

choice = int(input("Enter your choice: "))

if choice == 1:
    print("Your Balance =", balance)

elif choice == 2:
    amount = int(input("Enter amount to withdraw: "))

    if amount <= balance:
        balance = balance - amount
        print("Withdrawal Successful")
        print("Remaining Balance =", balance)
    else:
        print("Insufficient Balance")

elif choice == 3:
    amount = int(input("Enter amount to deposit: "))
    balance = balance + amount
    print("Deposit Successful")
    print("Updated Balance =", balance)

else:
    print("Invalid Option")
# Out:
# 1. Check Balance
# 2. Withdraw Money
# 3. Deposit Money
# Enter your choice:  3
# Enter amount to deposit:  2
# Deposit Successful
# Updated Balance = 10002

# %%
income = float(input("Enter your income: "))

if income < 250000:
    tax = 0
elif income >= 250000 and income <= 500000:
    tax = income * 0.05
elif income > 500000 and income <= 1000000:
    tax = income * 0.20
else:
    tax = income * 0.30

print("Income Tax =", tax)
# Out:
# Enter your income:  500000
# Income Tax = 25000.0

# %%
a = float(input("Enter value of a: "))
b = float(input("Enter value of b: "))
c = float(input("Enter value of c: "))

discriminant = (b ** 2) - (4 * a * c)

if discriminant > 0:
    print("Roots are Real and Different")
elif discriminant == 0:
    print("Roots are Real and Equal")
else:
    print("Roots are Imaginary")
# Out:
# Enter value of a:  7325
# Enter value of b:  6325
# Enter value of c:  3424
# Roots are Imaginary

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = int(input("Enter your choice: "))

if choice == 1:
    print("Result =", num1 + num2)
elif choice == 2:
    print("Result =", num1 - num2)
elif choice == 3:
    print("Result =", num1 * num2)
elif choice == 4:
    if num2 != 0:
        print("Result =", num1 / num2)
    else:
        print("Division by zero is not possible")
else:
    print("Invalid Choice")
# Out:
# Enter first number:  554
# Enter second number:  54
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter your choice:  3
# Result = 29916.0

# %%
a = int(input("Enter first angle: "))
b = int(input("Enter second angle: "))
c = int(input("Enter third angle: "))

if a + b + c == 180:
    print("Valid Triangle")
else:
    print("Invalid Triangle")
# Out:
# Enter first angle:  60
# Enter second angle:  60
# Enter third angle:  60
# Valid Triangle

# %%
month = int(input("Enter month number (1-12): "))

if month in [12, 1, 2]:
    print("Winter Season")
elif month in [3, 4, 5]:
    print("Summer Season")
elif month in [6, 7, 8]:
    print("Rainy Season")
elif month in [9, 10, 11]:
    print("Autumn Season")
else:
    print("Invalid Month Number")
# Out:
# Enter month number (1-12):  4
# Summer Season

# %%
amount = float(input("Enter shopping amount: "))

if amount >= 5000:
    discount = amount * 0.20
elif amount >= 3000:
    discount = amount * 0.10
elif amount >= 1000:
    discount = amount * 0.05
else:
    discount = 0

final_amount = amount - discount

print("Discount =", discount)
print("Final Amount =", final_amount)
# Out:
# Enter shopping amount:  654
# Discount = 0
# Final Amount = 654.0

# %%
# Program for online shopping discount system

purchase = float(input("Enter purchase amount (₹): "))

if purchase > 5000:
    discount = 0.30 * purchase
elif purchase >= 2000:
    discount = 0.20 * purchase
else:
    discount = 0.10 * purchase

final_amount = purchase - discount

print(f"Discount: ₹{discount:.2f}")
print(f"Final amount to pay: ₹{final_amount:.2f}")
# Out:
# Enter purchase amount (₹):  5433
# Discount: ₹1629.90
# Final amount to pay: ₹3803.10

# %%
# Program to assign employee performance ratings

score = int(input("Enter employee score: "))

if score >= 90:
    rating = "Excellent"
elif score >= 70:
    rating = "Good"
elif score >= 50:
    rating = "Average"
else:
    rating = "Poor"

print(f"Employee Rating: {rating}")
# Out:
# Enter employee score:  65
# Employee Rating: Average
